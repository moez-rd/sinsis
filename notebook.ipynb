# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# %%
frequency_sampling, audio_signal = wavfile.read("Tonmoy 07.wav")

# %%
frequency_sampling
# Out:
# 16000

# %%
audio_signal
# Out:
# array([-1, -2, -3, ..., -2, -1, -1], dtype=int16)

# %%
audio_signal = audio_signal[:100]
time_axis = 1000 * np.arange(0, len(audio_signal), 1) / float(frequency_sampling)

# %%
plt.plot(time_axis, audio_signal)
plt.xlabel('Time (milliseconds)')
plt.ylabel('Amplitude')
plt.title('Input audio signal')
plt.show()

# %%
# Plot the results
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
plt.plot(time_axis, audio_signal)
plt.title('Continuous Signal')

plt.subplot(2, 1, 2)
plt.stem(time_axis, audio_signal, markerfmt='bo', linefmt='b-')
plt.title('Discrete Signal (Sampled)')
plt.show()
